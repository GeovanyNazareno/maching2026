# %% [markdown]
# <img src=img/itq.jpg>

# %% [markdown]
# ![logo](img/python.jpg)
#
# Geovanny Nazareno

# %%
# Creación aleatoria de datos
import numpy as np
import random
random.seed(42)

# %%
nivel_estudios = []
nivel_estudios.extend(['Secundaria']*110)
nivel_estudios.extend(['Bachillerato']*172)
nivel_estudios.extend(['Grado']*145)
nivel_estudios.extend(['Master']*52)
nivel_estudios.extend(['Doctorado']*21)

nivel_estudios = np.random.permutation(nivel_estudios)

# %%
print(nivel_estudios)
# Out:
# ['Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Master' 'Bachillerato' 'Secundaria' 'Grado'
#  'Grado' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Master' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Secundaria' 'Grado' 'Grado'
#  'Bachillerato' 'Secundaria' 'Doctorado' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Secundaria' 'Secundaria'
#  'Grado' 'Bachillerato' 'Secundaria' 'Master' 'Secundaria' 'Grado' 'Grado'
#  'Doctorado' 'Master' 'Bachillerato' 'Bachillerato' 'Grado' 'Master'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado' 'Doctorado'
#  'Bachillerato' 'Grado' 'Grado' 'Grado' 'Bachillerato' 'Grado' 'Grado'
#  'Secundaria' 'Secundaria' 'Grado' 'Grado' 'Grado' 'Secundaria' 'Grado'
#  'Secundaria' 'Master' 'Bachillerato' 'Secundaria' 'Grado' 'Master'
#  'Grado' 'Grado' 'Bachillerato' 'Grado' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato' 'Master' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Grado' 'Grado' 'Secundaria' 'Grado' 'Grado' 'Bachillerato' 'Grado'
#  'Grado' 'Secundaria' 'Grado' 'Secundaria' 'Grado' 'Grado' 'Bachillerato'
#  'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado'
#  'Secundaria' 'Secundaria' 'Secundaria' 'Secundaria' 'Secundaria' 'Master'
#  'Secundaria' 'Grado' 'Grado' 'Bachillerato' 'Secundaria' 'Master'
#  'Master' 'Secundaria' 'Secundaria' 'Bachillerato' 'Grado' 'Grado' 'Grado'
#  'Master' 'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Doctorado' 'Secundaria'
#  'Grado' 'Secundaria' 'Master' 'Bachillerato' 'Grado' 'Master' 'Master'
#  'Doctorado' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Grado' 'Grado' 'Bachillerato' 'Doctorado' 'Grado' 'Doctorado' 'Master'
#  'Bachillerato' 'Bachillerato' 'Master' 'Master' 'Bachillerato' 'Master'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Grado' 'Master' 'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria'
#  'Secundaria' 'Master' 'Secundaria' 'Bachillerato' 'Master' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria' 'Master' 'Master'
#  'Bachillerato' 'Doctorado' 'Bachillerato' 'Bachillerato' 'Master'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Grado' 'Master' 'Grado'
#  'Master' 'Doctorado' 'Doctorado' 'Master' 'Bachillerato' 'Grado'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado'
#  'Secundaria' 'Grado' 'Secundaria' 'Secundaria' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Master' 'Grado' 'Bachillerato'
#  'Secundaria' 'Grado' 'Grado' 'Grado' 'Grado' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado'
#  'Secundaria' 'Grado' 'Grado' 'Doctorado' 'Grado' 'Master' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Doctorado' 'Bachillerato'
#  'Secundaria' 'Master' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado'
#  'Secundaria' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Master'
#  'Bachillerato' 'Grado' 'Doctorado' 'Bachillerato' 'Grado' 'Grado'
#  'Doctorado' 'Master' 'Grado' 'Secundaria' 'Bachillerato' 'Secundaria'
#  'Grado' 'Master' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado'
#  'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Grado' 'Doctorado' 'Grado' 'Bachillerato' 'Grado'
#  'Doctorado' 'Bachillerato' 'Grado' 'Master' 'Secundaria' 'Grado'
#  'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Doctorado'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Master'
#  'Grado' 'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Secundaria' 'Grado' 'Bachillerato' 'Grado' 'Secundaria' 'Grado'
#  'Grado' 'Master' 'Bachillerato' 'Secundaria' 'Doctorado' 'Bachillerato'
#  'Grado' 'Master' 'Grado' 'Bachillerato' 'Master' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Secundaria' 'Grado'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato'
#  'Grado' 'Grado' 'Secundaria' 'Doctorado' 'Secundaria' 'Bachillerato'
#  'Grado' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado'
#  'Secundaria' 'Grado' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Master' 'Grado' 'Secundaria' 'Master' 'Master' 'Grado'
#  'Bachillerato' 'Master' 'Secundaria' 'Grado' 'Master' 'Grado'
#  'Bachillerato' 'Grado' 'Master' 'Bachillerato' 'Grado' 'Secundaria'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato'
#  'Master' 'Secundaria' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato' 'Grado' 'Master'
#  'Doctorado' 'Bachillerato' 'Grado' 'Grado' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Master' 'Secundaria' 'Secundaria' 'Bachillerato' 'Master'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado'
#  'Grado' 'Master' 'Grado' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Grado' 'Grado' 'Secundaria' 'Grado'
#  'Bachillerato' 'Grado' 'Master' 'Master' 'Secundaria' 'Secundaria'
#  'Secundaria' 'Doctorado']

# %%
# DIAGRAMA DE BARRAS
import matplotlib.pyplot as plt
import numpy as np
estudios, frecuencia = np.unique(nivel_estudios, return_counts=True)
print(estudios, frecuencia)
# Out:
# ['Bachillerato' 'Doctorado' 'Grado' 'Master' 'Secundaria'] [172  21 145  52 110]

# %%
plt.ylabel('Frecuencia absoluta')
plt.xlabel('Nivel de estudios')
plt.title('Diagrama de barras')
plt.bar(estudios, frecuencia) # https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html
plt.show()

# %%
# DIAGRAMA DE SECTORES
colores = {'red', 'blue', 'orange', 'green', 'cyan'}
plt.pie(frecuencia, labels=estudios, colors=colores, autopct='%1.2f%%')
plt.title('Diagrama de sectores')
plt.show()

# %%
# Tarea implementar con pandas esta información

# %%
import pandas as pd

# %%
# Crear DataFrame
df = pd.DataFrame({'Nivel_Estudios': nivel_estudios})

df.head()
# Out:
#   Nivel_Estudios
# 0   Bachillerato
# 1          Grado
# 2   Bachillerato
# 3   Bachillerato
# 4   Bachillerato

# %%
#Calculo la frecuencia
frecuencia = df['Nivel_Estudios'].value_counts()

print(frecuencia)
# Out:
# Nivel_Estudios
# Bachillerato    172
# Grado           145
# Secundaria      110
# Master           52
# Doctorado        21
# Name: count, dtype: int64

# %%
#Diagrama de barras
frecuencia.plot(kind='bar')

plt.ylabel('Frecuencia absoluta')
plt.xlabel('Nivel de estudios')
plt.title('Diagrama de barras')

plt.show()

# %%
##Diagrama de sectores
frecuencia.plot(kind='pie', autopct='%1.2f%%')

plt.title('Diagrama de sectores')
plt.ylabel('')

plt.show()

# %% [markdown]
# https://github.com/GeovanyNazareno/maching2026.git
