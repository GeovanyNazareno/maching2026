# %% [markdown]
# *Geovanny Nazareno* <br>
# **nombre del proyecto**
# - Sistema de clasificación automática de enfermedades en tomates

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
##Crear la matriz con NumPy (enfermedades y cantidades)
conteo_clases = {
    'Bacterial_spot': 1702,
    'Early_blight': 1920,
    'Late_blight': 1851,
    'Leaf_Mold': 1882,
    'Septoria_leaf_spot': 1745,
    'Spider_mites': 1741,
    'Target_Spot': 1827,
    'Yellow_Leaf_Curl_Virus': 1961,
    'Tomato_mosaic_virus': 1790,
    'Healthy': 1926
}

enfermedades = np.array(list(conteo_clases.keys()))
cantidades = np.array(list(conteo_clases.values()))

enfermedades, cantidades
# Out:
# (array(['Bacterial_spot', 'Early_blight', 'Late_blight', 'Leaf_Mold',
#         'Septoria_leaf_spot', 'Spider_mites', 'Target_Spot',
#         'Yellow_Leaf_Curl_Virus', 'Tomato_mosaic_virus', 'Healthy'],
#        dtype='<U22'),
#  array([1702, 1920, 1851, 1882, 1745, 1741, 1827, 1961, 1790, 1926]))

# %%
##Mostrar la matriz completa
matriz = np.column_stack((enfermedades, cantidades))
matriz
# Out:
# array([['Bacterial_spot', '1702'],
#        ['Early_blight', '1920'],
#        ['Late_blight', '1851'],
#        ['Leaf_Mold', '1882'],
#        ['Septoria_leaf_spot', '1745'],
#        ['Spider_mites', '1741'],
#        ['Target_Spot', '1827'],
#        ['Yellow_Leaf_Curl_Virus', '1961'],
#        ['Tomato_mosaic_virus', '1790'],
#        ['Healthy', '1926']], dtype='<U22')

# %%
#Saber cuántas enfermedades hay (sin contar sanos)
numero_enfermedades = len(enfermedades) - 1
print("Cantidad de enfermedades:", numero_enfermedades)
# Out:
# Cantidad de enfermedades: 9

# %%
#Calcular cuántos tomates enfermos hay
tomates_sanos = conteo_clases['Healthy']
total_enfermos = total_imagenes - tomates_sanos

print("Tomates enfermos:", total_enfermos)
# Out:
# Tomates enfermos: 16419

# %%
#Crear gráfico de puntos (Scatter Plot)

x = np.arange(len(enfermedades))
y = cantidades

plt.figure()
plt.scatter(x, y)
plt.xticks(x, enfermedades, rotation=90, ha='right')
plt.xlabel("Tipo de enfermedad")
plt.ylabel("Cantidad de imágenes")
plt.title("Gráfico de puntos: Casos por enfermedad")
plt.show()
